# %%
from tensorflow.keras.datasets import reuters

(train_data, train_labels),(test_data, test_labels) = reuters.load_data(num_words=10000)

# %%
import numpy as np

def vectorize_sequence(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    for j in sequence:
      results[i][j] = 1.
  return results

x_train = vectorize_sequence(train_data)
x_test = vectorize_sequence(test_data)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model2 = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %%
model2.compile(
    loss = keras.losses.CategoricalCrossentropy(),
    optimizer = keras.optimizers.RMSprop(),
    metrics=["accuracy"]
)

# %%
x_val = x_train[:1000]
partial_xtrain = x_train[1000:]

y_val = y_train[:1000]
partial_ytrain = y_train[1000:]

# %%
history = model2.fit(
    partial_xtrain,
    partial_ytrain,
    batch_size=512,
    epochs=20,
    validation_data=(x_val,y_val)
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3823 - loss: 3.2294 - val_accuracy: 0.6430 - val_loss: 1.7850
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6893 - loss: 1.5796 - val_accuracy: 0.6880 - val_loss: 1.3519
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7348 - loss: 1.1902 - val_accuracy: 0.7250 - val_loss: 1.1966
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7815 - loss: 0.9685 - val_accuracy: 0.7660 - val_loss: 1.0795
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8256 - loss: 0.8058 - val_accuracy: 0.7870 - val_loss: 1.0061
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8588 - loss: 0.6686 - val_accuracy: 0.7910 - val_loss: 0.9801
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8824 - loss: 0.5552 - val_accuracy: 0.8100 - val_loss: 0.9248
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt

loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(46, activation='softmax')
])

# %%
model.compile(
    loss = keras.losses.CategoricalCrossentropy(),
    optimizer = keras.optimizers.RMSprop(),
    metrics=["accuracy"]
)

# %%
history = model.fit(
    partial_xtrain,
    partial_ytrain,
    batch_size=516,
    epochs=10,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.3967 - loss: 3.2732 - val_accuracy: 0.6170 - val_loss: 1.9051
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.6627 - loss: 1.6972 - val_accuracy: 0.7020 - val_loss: 1.3744
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7290 - loss: 1.2423 - val_accuracy: 0.7270 - val_loss: 1.1854
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7884 - loss: 0.9553 - val_accuracy: 0.7650 - val_loss: 1.0725
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8212 - loss: 0.8174 - val_accuracy: 0.7820 - val_loss: 1.0225
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8536 - loss: 0.6849 - val_accuracy: 0.7970 - val_loss: 0.9540
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8813 - loss: 0.5735 - val_accuracy: 0.8090 - val_loss: 0.9181
# Epoch 8/10
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7717 - loss: 1.0171
# [1.036953330039978, 0.7617987394332886]

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
predictions.shape
# Out:
# (2246, 46)

# %%
count_correct = 0
print(f"{'Sample':<8} | {'Highest Softmax':<15} | {'Predicted Category':<20} | {'Actual Category':<15} | {'Is Correct?':<10}")
print("-" * 80)
for i in range(50):
    is_correct = 1 if np.argmax(predictions[i]) == test_labels[i] else 0
    count_correct += is_correct
    print(f"{i:<8} | {max(predictions[i]):<15.6f} | {np.argmax(predictions[i]):<20} | {test_labels[i]:<15} | {is_correct:<10}")

print(f"correct predictions: {count_correct}/50")
# Out:
# Sample   | Highest Softmax | Predicted Category   | Actual Category | Is Correct?
# --------------------------------------------------------------------------------
# 0        | 0.992172        | 3                    | 3               | 1
# 1        | 0.684275        | 10                   | 10              | 1
# 2        | 0.847234        | 1                    | 1               | 1
# 3        | 0.726594        | 3                    | 4               | 0
# 4        | 0.935075        | 13                   | 4               | 0
# 5        | 0.997001        | 3                    | 3               | 1
# 6        | 0.999527        | 3                    | 3               | 1
# 7        | 0.999672        | 3                    | 3               | 1
# 8        | 0.999862        | 3                    | 3               | 1
# 9        | 0.993155        | 3                    | 3               | 1
# 10       | 0.759828        | 1                    | 5               | 0
# ...

# %% [markdown]
# 1. load data
# 2. vectorise inputs
# 3. format labels
# 4. define model
# 5. compile model
# 6. make validation set
# 7. train model
# 8. generate graphs
# 9. retrain to avoid overfitting
# 10. evaluate retrained model
# 11. predict using retrained model
