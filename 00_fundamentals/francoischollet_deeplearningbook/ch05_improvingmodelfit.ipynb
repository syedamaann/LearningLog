# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from keras import layers

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer=keras.optimizers.RMSprop(1.),  # learning rate is too high, so train_acc and val_acc stays in 20%-30% range ==> model is not able to train
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history = model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.3744 - loss: 3884.0559 - val_accuracy: 0.1838 - val_loss: 2.2195
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1805 - loss: 3.6261 - val_accuracy: 0.1751 - val_loss: 2.1784
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1729 - loss: 2.4841 - val_accuracy: 0.1965 - val_loss: 2.2513
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1962 - loss: 2.3102 - val_accuracy: 0.1700 - val_loss: 2.2714
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1672 - loss: 2.5750 - val_accuracy: 0.1548 - val_loss: 2.3550
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1547 - loss: 2.5211 - val_accuracy: 0.1256 - val_loss: 2.3366
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1617 - loss: 2.4452 - val_accuracy: 0.1723 - val_loss: 2.2523
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'][1:], label='Training Loss')
plt.plot(history.history['val_loss'][1:], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer=keras.optimizers.RMSprop(1e-2),   # learning rate is accurate, so train_acc and val_acc goes up ==> model is able to train
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history = model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8338 - loss: 0.7869 - val_accuracy: 0.9553 - val_loss: 0.1497
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9650 - loss: 0.1220 - val_accuracy: 0.9641 - val_loss: 0.1317
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9754 - loss: 0.0882 - val_accuracy: 0.9630 - val_loss: 0.1653
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9798 - loss: 0.0750 - val_accuracy: 0.9724 - val_loss: 0.1452
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9840 - loss: 0.0650 - val_accuracy: 0.9718 - val_loss: 0.1704
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9851 - loss: 0.0561 - val_accuracy: 0.9720 - val_loss: 0.1680
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9876 - loss: 0.0529 - val_accuracy: 0.9710 - val_loss: 0.2064
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'][1:], label='Training Loss')
plt.plot(history.history['val_loss'][1:], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model = keras.Sequential([layers.Dense(10, activation="softmax")])    # low model capacity ==> val_loss goes down, keeps going down slowly and almost stalls
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_small_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7324 - loss: 1.0502 - val_accuracy: 0.9027 - val_loss: 0.3607
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8979 - loss: 0.3688 - val_accuracy: 0.9149 - val_loss: 0.3105
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9101 - loss: 0.3212 - val_accuracy: 0.9187 - val_loss: 0.2918
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9127 - loss: 0.3076 - val_accuracy: 0.9211 - val_loss: 0.2847
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9176 - loss: 0.2901 - val_accuracy: 0.9229 - val_loss: 0.2785
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9203 - loss: 0.2882 - val_accuracy: 0.9237 - val_loss: 0.2755
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9272 - loss: 0.2697 - val_accuracy: 0.9253 - val_loss: 0.2727
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b--",
         label="Validation loss")
plt.title("Effect of insufficient model capacity on validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
model = keras.Sequential([
    layers.Dense(96, activation="relu"),
    layers.Dense(96, activation="relu"),
    layers.Dense(10, activation="softmax"),       # accurate model capacity ==> val_loss goes down and then increases (which means, we are able to achieve overfitting)
])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_large_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8310 - loss: 0.6182 - val_accuracy: 0.9436 - val_loss: 0.1949
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9498 - loss: 0.1713 - val_accuracy: 0.9593 - val_loss: 0.1412
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9662 - loss: 0.1143 - val_accuracy: 0.9647 - val_loss: 0.1143
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9735 - loss: 0.0903 - val_accuracy: 0.9687 - val_loss: 0.1136
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9778 - loss: 0.0736 - val_accuracy: 0.9718 - val_loss: 0.0975
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9814 - loss: 0.0620 - val_accuracy: 0.9688 - val_loss: 0.1034
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9856 - loss: 0.0502 - val_accuracy: 0.9719 - val_loss: 0.0964
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
val_loss = history_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b--",
         label="Validation loss")
plt.title("validation loss for model with appropriate capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
